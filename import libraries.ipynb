# %%
#Import libraries

# %%
import sys

# !{sys.executable} -m pip install pandas numpy
# Out:
# Requirement already satisfied: pandas in c:\users\joel\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\joel\anaconda3\lib\site-packages (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\joel\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\joel\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\joel\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\joel\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# %pip install matplotlib seaborn
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: matplotlib in c:\users\joel\anaconda3\lib\site-packages (3.10.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: seaborn in c:\users\joel\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\joel\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\joel\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\joel\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\joel\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\joel\anaconda3\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\joel\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\joel\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\joel\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\joel\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\joel\anaconda3\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\joel\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\joel\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\joel\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# %pip install scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
# Out:
# Requirement already satisfied: scikit-learn in c:\users\joel\anaconda3\lib\site-packages (1.6.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.19.5 in c:\users\joel\anaconda3\lib\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\joel\anaconda3\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\joel\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\joel\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
    ConfusionMatrixDisplay
)

# %%
from sklearn.feature_selection import (
    mutual_info_classif,
    SelectKBest,
    f_classif
)

# %%
# %pip install xgboost
from xgboost import XGBClassifier
# Out:
# Collecting xgboost
#   Downloading xgboost-3.3.0-py3-none-win_amd64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in c:\users\joel\anaconda3\lib\site-packages (from xgboost) (2.1.3)
# Requirement already satisfied: scipy in c:\users\joel\anaconda3\lib\site-packages (from xgboost) (1.15.3)
# Downloading xgboost-3.3.0-py3-none-win_amd64.whl (69.5 MB)
#    ---------------------------------------- 0.0/69.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/69.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/69.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/69.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/69.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/69.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/69.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/69.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/69.5 MB ? eta -:--:--
#    ---------------------------------------- 0.5/69.5 MB 476.1 kB/s eta 0:02:25
#    ---------------------------------------- 0.5/69.5 MB 476.1 kB/s eta 0:02:25
#    ---------------------------------------- 0.5/69.5 MB 476.1 kB/s eta 0:02:25
#    ---------------------------------------- 0.8/69.5 MB 432.0 kB/s eta 0:02:40
#    ---------------------------------------- 0.8/69.5 MB 432.0 kB/s eta 0:02:40
#    ---------------------------------------- 0.8/69.5 MB 432.0 kB/s eta 0:02:40
#    ---------------------------------------- 0.8/69.5 MB 432.0 kB/s eta 0:02:40
#    ---------------------------------------- 0.8/69.5 MB 432.0 kB/s eta 0:02:40
#     --------------------------------------- 1.0/69.5 MB 335.7 kB/s eta 0:03:24
#     --------------------------------------- 1.0/69.5 MB 335.7 kB/s eta 0:03:24
#     --------------------------------------- 1.0/69.5 MB 335.7 kB/s eta 0:03:24
#     --------------------------------------- 1.0/69.5 MB 335.7 kB/s eta 0:03:24
#     --------------------------------------- 1.0/69.5 MB 335.7 kB/s eta 0:03:24
#     --------------------------------------- 1.3/69.5 MB 318.9 kB/s eta 0:03:34
#     --------------------------------------- 1.3/69.5 MB 318.9 kB/s eta 0:03:34
#     --------------------------------------- 1.3/69.5 MB 318.9 kB/s eta 0:03:34
#     --------------------------------------- 1.3/69.5 MB 318.9 kB/s eta 0:03:34
#     --------------------------------------- 1.3/69.5 MB 318.9 kB/s eta 0:03:34
#     --------------------------------------- 1.3/69.5 MB 318.9 kB/s eta 0:03:34
#     --------------------------------------- 1.3/69.5 MB 318.9 kB/s eta 0:03:34
#     --------------------------------------- 1.3/69.5 MB 318.9 kB/s eta 0:03:34
#     --------------------------------------- 1.3/69.5 MB 318.9 kB/s eta 0:03:34
#     --------------------------------------- 1.3/69.5 MB 318.9 kB/s eta 0:03:34
#     --------------------------------------- 1.6/69.5 MB 244.1 kB/s eta 0:04:39
#    - -------------------------------------- 2.1/69.5 MB 320.4 kB/s eta 0:03:31
#    - -------------------------------------- 2.4/69.5 MB 354.5 kB/s eta 0:03:10
#    - -------------------------------------- 2.6/69.5 MB 389.7 kB/s eta 0:02:52
#    - -------------------------------------- 2.9/69.5 MB 414.9 kB/s eta 0:02:41
#    - -------------------------------------- 3.1/69.5 MB 436.6 kB/s eta 0:02:33
#    - -------------------------------------- 3.1/69.5 MB 436.6 kB/s eta 0:02:33
#    - -------------------------------------- 3.4/69.5 MB 458.9 kB/s eta 0:02:25
#    -- ------------------------------------- 3.7/69.5 MB 482.7 kB/s eta 0:02:17
#    -- ------------------------------------- 3.9/69.5 MB 505.1 kB/s eta 0:02:10
#    -- ------------------------------------- 4.2/69.5 MB 519.9 kB/s eta 0:02:06
#    -- ------------------------------------- 4.5/69.5 MB 537.5 kB/s eta 0:02:02
#    -- ------------------------------------- 4.5/69.5 MB 537.5 kB/s eta 0:02:02
#    -- ------------------------------------- 5.0/69.5 MB 566.3 kB/s eta 0:01:54
#    --- ------------------------------------ 5.2/69.5 MB 585.8 kB/s eta 0:01:50
#    --- ------------------------------------ 5.5/69.5 MB 604.2 kB/s eta 0:01:46
#    --- ------------------------------------ 5.8/69.5 MB 622.1 kB/s eta 0:01:43
#    --- ------------------------------------ 6.0/69.5 MB 640.4 kB/s eta 0:01:40
2 MB/s eta 0:00:44
#    ----------- ---------------------------- 19.9/69.5 MB 1.2 MB/s eta 0:00:43
#    ----------- ---------------------------- 20.4/69.5 MB 1.2 MB/s eta 0:00:43
#    ----------- ---------------------------- 20.7/69.5 MB 1.2 MB/s eta 0:00:42
#    ------------ --------------------------- 21.0/69.5 MB 1.2 MB/s eta 0:00:42
#    ------------ --------------------------- 21.2/69.5 MB 1.2 MB/s eta 0:00:42
#    ------------ --------------------------- 21.8/69.5 MB 1.2 MB/s eta 0:00:41
#    ------------ --------------------------- 22.0/69.5 MB 1.2 MB/s eta 0:00:41
#    ------------ --------------------------- 22.5/69.5 MB 1.2 MB/s eta 0:00:40
#    ------------- -------------------------- 22.8/69.5 MB 1.2 MB/s eta 0:00:39
#    ------------- -------------------------- 23.3/69.5 MB 1.2 MB/s eta 0:00:39
#    ------------- -------------------------- 23.6/69.5 MB 1.2 MB/s eta 0:00:38
#    ------------- -------------------------- 24.1/69.5 MB 1.2 MB/s eta 0:00:37
#    -------------- ------------------------- 24.4/69.5 MB 1.2 MB/s eta 0:00:37
#    -------------- ------------------------- 24.6/69.5 MB 1.2 MB/s eta 0:00:37
#    -------------- ------------------------- 24.9/69.5 MB 1.2 MB/s eta 0:00:37
#    -------------- ------------------------- 25.2/69.5 MB 1.2 MB/s eta 0:00:36
#    -------------- ------------------------- 25.4/69.5 MB 1.2 MB/s eta 0:00:36
#    -------------- ------------------------- 25.7/69.5 MB 1.2 MB/s eta 0:00:36
#    --------------- ------------------------ 26.2/69.5 MB 1.2 MB/s eta 0:00:35
#    --------------- ------------------------ 26.5/69.5 MB 1.2 MB/s eta 0:00:35
#    --------------- ------------------------ 26.7/69.5 MB 1.2 MB/s eta 0:00:35
#    --------------- ------------------------ 27.0/69.5 MB 1.2 MB/s eta 0:00:35
#    --------------- ------------------------ 27.3/69.5 MB 1.2 MB/s eta 0:00:35
#    --------------- ------------------------ 27.5/69.5 MB 1.2 MB/s eta 0:00:34
#    --------------- ------------------------ 27.5/69.5 MB 1.2 MB/s eta 0:00:34
#    --------------- ------------------------ 27.8/69.5 MB 1.2 MB/s eta 0:00:34
#    ---------------- ----------------------- 28.0/69.5 MB 1.2 MB/s eta 0:00:34
#    ---------------- ----------------------- 28.0/69.5 MB 1.2 MB/s eta 0:00:34
#    ---------------- ----------------------- 28.0/69.5 MB 1.2 MB/s eta 0:00:34
#    ---------------- ----------------------- 28.0/69.5 MB 1.2 MB/s eta 0:00:34
#    ---------------- ----------------------- 28.3/69.5 MB 1.2 MB/s eta 0:00:35
#    ---------------- ----------------------- 28.6/69.5 MB 1.2 MB/s eta 0:00:35
#    ---------------- ----------------------- 28.8/69.5 MB 1.2 MB/s eta 0:00:34
#    ---------------- ----------------------- 29.4/69.5 MB 1.2 MB/s eta 0:00:34
#    ----------------- ---------------------- 29.6/69.5 MB 1.2 MB/s eta 0:00:34
#    ----------------- ---------------------- 29.6/69.5 MB 1.2 MB/s eta 0:00:34
#    ----------------- ---------------------- 29.9/69.5 MB 1.2 MB/s eta 0:00:34
#    ----------------- ---------------------- 29.9/69.5 MB 1.2 MB/s eta 0:00:34
#    ----------------- ---------------------- 30.1/69.5 MB 1.2 MB/s eta 0:00:34
#    ----------------- ---------------------- 30.4/69.5 MB 1.2 MB/s eta 0:00:33
#    ----------------- ---------------------- 30.4/69.5 MB 1.2 MB/s eta 0:00:33
#    ----------------- ---------------------- 30.7/69.5 MB 1.2 MB/s eta 0:00:33
#    ----------------- ---------------------- 30.9/69.5 MB 1.2 MB/s eta 0:00:33
#    ----------------- ---------------------- 31.2/69.5 MB 1.2 MB/s eta 0:00:33
#    ----------------- ---------------------- 31.2/69.5 MB 1.2 MB/s eta 0:00:33
#    ------------------ --------------------- 31.5/69.5 MB 1.2 MB/s eta 0:00:33
#    ------------------ --------------------- 31.5/69.5 MB 1.2 MB/s eta 0:00:33
#    ------------------ --------------------- 31.5/69.5 MB 1.2 MB/s eta 0:00:33
#    ------------------ --------------------- 31.5/69.5 MB 1.2 MB/s eta 0:00:33
#    ------------------ --------------------- 31.5/69.5 MB 1.2 MB/s eta 0:00:33
#    ------------------ --------------------- 31.7/69.5 MB 1.1 MB/s eta 0:00:34
#    ------------------ --------------------- 32.0/69.5 MB 1.1 MB/s eta 0:00:34
#    ------------------ --------------------- 32.0/69.5 MB 1.1 MB/s eta 0:00:34
#    ------------------ --------------------- 32.2/69.5 MB 1.1 MB/s eta 0:00:34
#    ------------------ --------------------- 32.5/69.5 MB 1.1 MB/s eta 0:00:33
#    ------------------ --------------------- 32.5/69.5 MB 1.1 MB/s eta 0:00:33
#    ------------------- -------------------- 33.0/69.5 MB 1.1 MB/s eta 0:00:33
#    ------------------- -------------------- 33.3/69.5 MB 1.1 MB/s eta 0:00:32
#    ------------------- -------------------- 33.6/69.5 MB 1.1 MB/s eta 0:00:32
#    ------------------- -------------------- 33.8/69.5 MB 1.1 MB/s eta 0:00:32
#    ------------------- -------------------- 34.1/69.5 MB 1.1 MB/s eta 0:00:32
#    ------------------- -------------------- 34.1/69.5 MB 1.1 MB/s eta 0:00:32
#    ------------------- -------------------- 34.1/69.5 MB 1.1 MB/s eta 0:00:32
#    ------------------- -------------------- 34.1/69.5 MB 1.1 MB/s eta 0:00:32
#    ------------------- -------------------- 34.3/69.5 MB 1.1 MB/s eta 0:00:31
#    ------------------- -------------------- 34.3/69.5 MB 1.1 MB/s eta 0:00:31
#    ------------------- -------------------- 34.6/69.5 MB 1.1 MB/s eta 0:00:31
#    ------------------- -------------------- 34.6/69.5 MB 1.1 MB/s eta 0:00:31
#    ------------------- -------------------- 34.6/69.5 MB 1.1 MB/s eta 0:00:31
#    -------------------- ------------------- 34.9/69.5 MB 1.2 MB/s eta 0:00:31
#    -------------------- -------------------
#    ----------------------------------- ---- 61.9/69.5 MB 590.3 kB/s eta 0:00:13
#    ----------------------------------- ---- 61.9/69.5 MB 590.3 kB/s eta 0:00:13
#    ----------------------------------- ---- 61.9/69.5 MB 590.3 kB/s eta 0:00:13
#    ----------------------------------- ---- 61.9/69.5 MB 590.3 kB/s eta 0:00:13
#    ----------------------------------- ---- 61.9/69.5 MB 590.3 kB/s eta 0:00:13
#    ----------------------------------- ---- 61.9/69.5 MB 590.3 kB/s eta 0:00:13
#    ----------------------------------- ---- 61.9/69.5 MB 590.3 kB/s eta 0:00:13
#    ----------------------------------- ---- 61.9/69.5 MB 590.3 kB/s eta 0:00:13
#    ----------------------------------- ---- 61.9/69.5 MB 590.3 kB/s eta 0:00:13
#    ----------------------------------- ---- 61.9/69.5 MB 590.3 kB/s eta 0:00:13
#    ------------------------------------ --- 62.9/69.5 MB 597.3 kB/s eta 0:00:12
#    ------------------------------------ --- 62.9/69.5 MB 597.3 kB/s eta 0:00:12
#    ------------------------------------ --- 62.9/69.5 MB 597.3 kB/s eta 0:00:12
#    ------------------------------------ --- 63.2/69.5 MB 595.2 kB/s eta 0:00:11
#    ------------------------------------ --- 63.7/69.5 MB 608.2 kB/s eta 0:00:10
#    ------------------------------------ --- 64.0/69.5 MB 614.2 kB/s eta 0:00:10
#    ------------------------------------ --- 64.2/69.5 MB 616.7 kB/s eta 0:00:09
#    ------------------------------------- -- 64.7/69.5 MB 622.7 kB/s eta 0:00:08
#    ------------------------------------- -- 65.0/69.5 MB 614.9 kB/s eta 0:00:08
#    ------------------------------------- -- 65.3/69.5 MB 615.9 kB/s eta 0:00:07
#    -------------------------------------- - 66.1/69.5 MB 642.2 kB/s eta 0:00:06
#    -------------------------------------- - 66.3/69.5 MB 646.7 kB/s eta 0:00:05
#    -------------------------------------- - 66.6/69.5 MB 651.6 kB/s eta 0:00:05
#    -------------------------------------- - 66.8/69.5 MB 659.0 kB/s eta 0:00:05
#    -------------------------------------- - 67.1/69.5 MB 665.0 kB/s eta 0:00:04
#    -------------------------------------- - 67.6/69.5 MB 673.8 kB/s eta 0:00:03
#    ---------------------------------------  67.9/69.5 MB 674.5 kB/s eta 0:00:03
#    ---------------------------------------  68.2/69.5 MB 677.7 kB/s eta 0:00:03
#    ---------------------------------------  68.4/69.5 MB 681.2 kB/s eta 0:00:02
#    ---------------------------------------  68.9/69.5 MB 693.2 kB/s eta 0:00:01
#    ---------------------------------------  69.5/69.5 MB 701.0 kB/s eta 0:00:01
#    ---------------------------------------  69.5/69.5 MB 701.0 kB/s eta 0:00:01
#    ---------------------------------------  69.5/69.5 MB 701.0 kB/s eta 0:00:01
#    ---------------------------------------- 69.5/69.5 MB 683.6 kB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-3.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install scikit-learn xgboost
# Out:
# Requirement already satisfied: scikit-learn in c:\users\joel\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: xgboost in c:\users\joel\anaconda3\lib\site-packages (3.3.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\joel\anaconda3\lib\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\joel\anaconda3\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\joel\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\joel\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\joel\anaconda3\lib\site-packages (1.45.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\joel\anaconda3\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\joel\anaconda3\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\joel\anaconda3\lib\site-packages (from streamlit) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\joel\anaconda3\lib\site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\joel\anaconda3\lib\site-packages (from streamlit) (2.1.3)
# Requirement already satisfied: packaging<25,>=20 in c:\users\joel\anaconda3\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\joel\anaconda3\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\joel\anaconda3\lib\site-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\joel\anaconda3\lib\site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\joel\anaconda3\lib\site-packages (from streamlit) (19.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\joel\anaconda3\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\joel\anaconda3\lib\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\joel\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\joel\anaconda3\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\joel\anaconda3\lib\site-packages (from streamlit) (4.0.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\joel\anaconda3\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\joel\anaconda3\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\joel\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\joel\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\joel\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (1.31.0)
# Requirement already satisfied: colorama in c:\users\joel\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\joel\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\joel\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\joel\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\joel\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\joel\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\joel\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joel\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\joel\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joel\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.4.26)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\joel\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\joel\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\joel\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\joel\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in c:\users\joel\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\joel\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.52.0-cp312-abi3-win_amd64.whl.metadata (26 kB)
# Requirement already satisfied: numpy>=2 in c:\users\joel\anaconda3\lib\site-packages (from shap) (2.1.3)
# Requirement already satisfied: scipy in c:\users\joel\anaconda3\lib\site-packages (from shap) (1.15.3)
# Requirement already satisfied: scikit-learn in c:\users\joel\anaconda3\lib\site-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in c:\users\joel\anaconda3\lib\site-packages (from shap) (2.2.3)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\joel\anaconda3\lib\site-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in c:\users\joel\anaconda3\lib\site-packages (from shap) (24.2)
# Collecting slicer==0.0.8 (from shap)
#   Downloading slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numba in c:\users\joel\anaconda3\lib\site-packages (from shap) (0.61.0)
# Requirement already satisfied: llvmlite in c:\users\joel\anaconda3\lib\site-packages (from shap) (0.44.0)
# Requirement already satisfied: cloudpickle in c:\users\joel\anaconda3\lib\site-packages (from shap) (3.0.0)
# Requirement already satisfied: colorama in c:\users\joel\anaconda3\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\joel\anaconda3\lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\joel\anaconda3\lib\site-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\joel\anaconda3\lib\site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\joel\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\joel\anaconda3\lib\site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\joel\anaconda3\lib\site-packages (from scikit-learn->shap) (3.5.0)
# Downloading shap-0.52.0-cp312-abi3-win_amd64.whl (499 kB)
# Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Installing collected packages: slicer, shap
#
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    ---------------------------------------- 2/2 [shap]
#
# Successfully installed shap-0.52.0 slicer-0.0.8
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\joel\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\joel\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\joel\anaconda3\lib\site-packages (5.24.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\joel\anaconda3\lib\site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in c:\users\joel\anaconda3\lib\site-packages (from plotly) (24.2)

# %%
# %pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\joel\anaconda3\lib\site-packages (4.67.1)
# Requirement already satisfied: colorama in c:\users\joel\anaconda3\lib\site-packages (from tqdm) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !git add .
# !git commit -m "Completed preprocessing module"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'joel@DESKTOP-US48IQ3.(none)')

# %%
# Run git command in a notebook shell (use !)
# !git branch
# Out:
# * joel-EDA
#   main

# %%
# Run git pull in notebook shell
# !git pull origin main
# Out:
# Already up to date.
# From https://github.com/elisheba2/FinTwin-ai
#  * branch            main       -> FETCH_HEAD

# %%
# !git push origin main
# Out:
# fatal: User cancelled dialog.
# bash: line 1: /dev/tty: No such device or address
# error: failed to execute prompt script (exit code 1)
# fatal: could not read Username for 'https://github.com': No such file or directory

# %%
# !git status
# !git add .
# !git commit -m "Describe what you changed"
# !git pull origin main
# !git push origin main
# Out:
# On branch joel-EDA
# nothing to commit, working tree clean
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'joel@DESKTOP-US48IQ3.(none)')
# Already up to date.
# From https://github.com/elisheba2/FinTwin-ai
#  * branch            main       -> FETCH_HEAD
# fatal: User cancelled dialog.
# bash: line 1: /dev/tty: No such device or address
# error: failed to execute prompt script (exit code 1)
# fatal: could not read Username for 'https://github.com': No such file or directory

# %%
# !git status
# Out:
# On branch joel-EDA
# nothing to commit, working tree clean

# %%
# !git remote -v
# Out:
# origin	https://github.com/elisheba2/FinTwin-ai.git (fetch)
# origin	https://github.com/elisheba2/FinTwin-ai.git (push)

# %%
# !git add .import libraries
# Out:
# fatal: pathspec '.import' did not match any files

# %%
# !git status
# Out:
# On branch joel-EDA
# nothing to commit, working tree clean

# %%
# !git add "import libraries.ipynb"

# %%
# !git add .

# %%
# !git status
# Out:
# On branch joel-EDA
# nothing to commit, working tree clean

# %%
# !git commit -m "Added library imports notebook"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'joel@DESKTOP-US48IQ3.(none)')

# %%
# !git push origin main
# Out:
# fatal: User cancelled dialog.
# bash: line 1: /dev/tty: No such device or address
# error: failed to execute prompt script (exit code 1)
# fatal: could not read Username for 'https://github.com': No such file or directory

# %%
# !git branch
# Out:
# * joel-EDA
#   main

# %%
# !git pull origin main
# Out:
# Already up to date.
# From https://github.com/elisheba2/FinTwin-ai
#  * branch            main       -> FETCH_HEAD

# %%
# !git push origin main
# Out:
# fatal: User cancelled dialog.
# bash: line 1: /dev/tty: No such device or address
# error: failed to execute prompt script (exit code 1)
# fatal: could not read Username for 'https://github.com': No such file or directory

# %%
file_path = "../data/Financial_Health_Digital_Twin.csv"

# %%
import os

# robustly find and list an existing data directory
candidates = ["../data"]
try:
    candidates += [os.path.dirname(p) for p in candidate_paths]
except NameError:
    pass
for v in ("file_path", "path"):
    if v in globals():
        candidates.append(os.path.dirname(globals()[v]))

# normalize and dedupe
checked = []
for c in candidates:
    if not c:
        continue
    c = os.path.abspath(os.path.expanduser(c))
    if c in checked:
        continue
    checked.append(c)
    if os.path.isdir(c):
        print("Found data directory:", c)
        print(os.listdir(c))
        break
else:
    print("No data directory found. Checked paths:")
    for p in checked:
        print("-", p)
# Out:
# No data directory found. Checked paths:
# - c:\Users\joel\Desktop\data

# %%
df = pd.read_csv(file_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df = pd.read_csv(file_path)
#
# NameError: name 'pd' is not defined

# %%
import os

os.getcwd()
# Out:
# 'c:\\Users\\eliza\\Desktop\\FinTwin-ai'

# %%
df.shape
# Out:
# (10000, 48)

# %%
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 10000
# Number of columns: 48

# %%
pd.set_option('display.max_columns', None)

df.head()
# Out:
#    Customer_ID  Age Gender       Country     Education Occupation  \
# 0            1   40      F       Nigeria       Primary      Nurse
# 1            2   27      M         Ghana  Postgraduate   Engineer
# 2            3   24      F        Rwanda       Diploma     Trader
# 3            4   51      M  South Africa       Diploma     Farmer
# 4            5   59      M         Ghana  Postgraduate     Trader
#
#   Marital_Status  Monthly_Income  Other_Income Income_Source  \
# 0         Single          376353        207001      Business
# 1        Married         1257292        161733         Mixed
# 2        Married          307601        268400      Business
# 3         Single          183636        114403        Salary
# 4         Single         1247703        167044        Salary
#
#    Monthly_Expenses  Monthly_Savings  Emergency_Fund  Savings_Rate  \
# 0            413022            59736          561913          0.10
# 1            933919           377122          108061          0.27
# 2            334061           200809          159367          0.35
# 3            230243            26476          259642          0.09
# 4           1236777           139412          540531          0.10
#
#    Loan_Amount  Monthly_Loan_Payment  Debt_to_Income_Ratio  Bank_Balance  \
# 0       394810                 11844                  0.02        767905
# 1      2439407                 73182                  0.05       1198902
# 2      2050859                 61525                  0.11        885365
# 3      1668903                 50067                  0.17        820880
# 4      2590371                 77711                  0.05       1374564
#
#    Mobile_Money_Balance  Number_of_Transactions  Cash_In  Cash_Out  Transfers  \
# 0                305548                      19   953893    532084        109
# 1                334974                      53   390487    102163        280
# 2                 20555                     176    81390    801710        285
# 3                480675                     132    84495    174447        229
# 4                354523                     194    56615    478825        286
#
#    Airtime_Purchases  Business_Type  Monthly_Revenue  Monthly_Profit  \
# 0               2457  Manufacturing           770977          138848
# 1              46668  Manufacturing           576712          126478
# 2              37553    Agriculture          2681904          407747
# 3              26322  Manufacturing          4659036          621290
# 4              25714           Food          3389250          575134
#
#    Supplier_Payments  Invoice_Value  POS_Sales Investment_Type  \
# 0             156497        1019413     346856          Stocks
# 1            1308157         873853     388143     Mutual Fund
# 2             744377        2502967    1805380          Crypto
# 3             297154        1815738    4077548          Crypto
# 4             227133        2029653    2538071         Savings
#
#    Investment_Value  Monthly_Return  Financial_Literacy_Score  \
# 0           1780562       -25086.25                        92
# 1           2230196        50757.54                        60
# 2           1913463       -25111.72                        31
# 3           1167782        59136.10                        65
# 4            261086         -245.17                        46
#
#    Spending_Discipline Risk_Tolerance  Saving_Consistency  Financial_Goal  \
# 0                   35           High                  48  Emergency Fund
# 1                   79         Medium                  94  Emergency Fund
# 2                   54           High                  80            Home
# 3                   68            Low                  49      Retirement
# 4                   76            Low                  40       Education
#
#    Financial_Health_Score Funding_Readiness Investment_Readiness  \
# 0                    42.6         Not Ready            Not Ready
# 1                    54.1         Not Ready            Not Ready
# 2                    39.5         Not Ready            Not Ready
# 3                    39.9         Not Ready            Not Ready
# 4                    37.6         Not Ready            Not Ready
#
#   Loan_Default_Risk  Predicted_Savings_12_Months  Predicted_Business_Growth  \
# 0               Low                       825054                       23.4
# 1               Low                      4727448                        2.5
# 2               Low                      2808902                       -3.2
# 3               Low                       296486                       -0.5
# 4               Low                      1733205                       -3.4
#
#   Budget_Recommendation Loan_Eligibility Recommended_Investment  \
# 0       Reduce Spending          Decline                 Crypto
# 1               Healthy           Review                 Stocks
# 2               Healthy          Decline            Mutual Fund
# 3       Reduce Spending          Decline                 Stocks
# 4       Reduce Spending          Decline         Treasury Bills
#
#   Financial_Risk_Level
# 0                 High
# 1               Medium
# 2                 High
# 3                 High
# 4                 High

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer_ID                  10000 non-null  int64
#  1   Age                          10000 non-null  int64
#  2   Gender                       10000 non-null  str
#  3   Country                      10000 non-null  str
#  4   Education                    10000 non-null  str
#  5   Occupation                   10000 non-null  str
#  6   Marital_Status               10000 non-null  str
#  7   Monthly_Income               10000 non-null  int64
#  8   Other_Income                 10000 non-null  int64
#  9   Income_Source                10000 non-null  str
#  10  Monthly_Expenses             10000 non-null  int64
#  11  Monthly_Savings              10000 non-null  int64
#  12  Emergency_Fund               10000 non-null  int64
#  13  Savings_Rate                 10000 non-null  float64
#  14  Loan_Amount                  10000 non-null  int64
#  15  Monthly_Loan_Payment         10000 non-null  int64
#  16  Debt_to_Income_Ratio         10000 non-null  float64
#  17  Bank_Balance                 10000 non-null  int64
#  18  Mobile_Money_Balance         10000 non-null  int64
#  19  Number_of_Transactions       10000 non-null  int64
#  20  Cash_In                      10000 non-null  int64
#  21  Cash_Out                     10000 non-null  int64
#  22  Transfers                    10000 non-null  int64
#  23  Airtime_Purchases            10000 non-null  int64
#  24  Business_Type                10000 non-null  str
#  25  Monthly_Revenue              10000 non-null  int64
#  26  Monthly_Profit               10000 non-null  int64
#  27  Supplier_Payments            10000 non-null  int64
#  28  Invoice_Value                10000 non-null  int64
#  29  POS_Sales                    10000 non-null  int64
#  30  Investment_Type              10000 non-null  str
#  31  Investment_Value             10000 non-null  int64
#  32  Monthly_Return               10000 non-null  float64
#  33  Financial_Literacy_Score     10000 non-null  int64
#  34  Spending_Discipline          10000 non-null  int64
#  35  Risk_Tolerance               10000 non-null  str
#  36  Saving_Consistency           10000 non-null  int64
#  37  Financial_Goal               10000 non-null  str
#  38  Financial_Health_Score       10000 non-null  float64
#  39  Funding_Readiness            10000 non-null  str
#  40  Investment_Readiness         10000 non-null  str
#  41  Loan_Default_Risk            10000 non-null  str
#  42  Predicted_Savings_12_Months  10000 non-null  int64
#  43  Predicted_Business_Growth    10000 non-null  float64
#  44  Budget_Recommendation        10000 non-null  str
#  45  Loan_Eligibility             10000 non-null  str
#  46  Recommended_Investment       10000 non-null  str
#  47  Financial_Risk_Level         10000 non-null  str
# dtypes: float64(5), int64(26), str(17)
# memory usage: 4.8 MB

# %%
missing_values = df.isnull().sum()

missing_values[missing_values > 0].sort_values(
    ascending=False
)
# Out:
# Series([], dtype: int64)

# %%
missing_percentage = (
    df.isnull().sum() / len(df) * 100
)

missing_percentage[
    missing_percentage > 0
].sort_values(
    ascending=False
)
# Out:
# Series([], dtype: float64)

# %%
duplicates = df.duplicated().sum()

print(
    "Duplicate rows:",
    duplicates
)
# Out:
# Duplicate rows: 0

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.replace(" ", "_")
    .str.replace("-", "_")
)

df.columns
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'Country', 'Education', 'Occupation',
#        'Marital_Status', 'Monthly_Income', 'Other_Income', 'Income_Source',
#        'Monthly_Expenses', 'Monthly_Savings', 'Emergency_Fund', 'Savings_Rate',
#        'Loan_Amount', 'Monthly_Loan_Payment', 'Debt_to_Income_Ratio',
#        'Bank_Balance', 'Mobile_Money_Balance', 'Number_of_Transactions',
#        'Cash_In', 'Cash_Out', 'Transfers', 'Airtime_Purchases',
#        'Business_Type', 'Monthly_Revenue', 'Monthly_Profit',
#        'Supplier_Payments', 'Invoice_Value', 'POS_Sales', 'Investment_Type',
#        'Investment_Value', 'Monthly_Return', 'Financial_Literacy_Score',
#        'Spending_Discipline', 'Risk_Tolerance', 'Saving_Consistency',
#        'Financial_Goal', 'Financial_Health_Score', 'Funding_Readiness',
#        'Investment_Readiness', 'Loan_Default_Risk',
#        'Predicted_Savings_12_Months', 'Predicted_Business_Growth',
#        'Budget_Recommendation', 'Loan_Eligibility', 'Recommended_Investment',
#        'Financial_Risk_Level'],
#       dtype='str')

# %%
duplicate_columns = df.columns[
    df.columns.duplicated()
]

duplicate_columns
# Out:
# Index([], dtype='str')

# %%
numeric_columns = df.select_dtypes(include='number').columns

numeric_columns

numeric_columns
# Out:
# Index(['Customer_ID', 'Age', 'Monthly_Income', 'Other_Income',
#        'Monthly_Expenses', 'Monthly_Savings', 'Emergency_Fund', 'Savings_Rate',
#        'Loan_Amount', 'Monthly_Loan_Payment', 'Debt_to_Income_Ratio',
#        'Bank_Balance', 'Mobile_Money_Balance', 'Number_of_Transactions',
#        'Cash_In', 'Cash_Out', 'Transfers', 'Airtime_Purchases',
#        'Monthly_Revenue', 'Monthly_Profit', 'Supplier_Payments',
#        'Invoice_Value', 'POS_Sales', 'Investment_Value', 'Monthly_Return',
#        'Financial_Literacy_Score', 'Spending_Discipline', 'Saving_Consistency',
#        'Financial_Health_Score', 'Predicted_Savings_12_Months',
#        'Predicted_Business_Growth'],
#       dtype='str')

# %%
for column in df.select_dtypes(include='number').columns:
    df[column] = df[column].fillna(df[column].median())

# %%
financial_columns = [
    "Monthly_Income",
    "Monthly_Expenses",
    "Monthly_Savings",
    "Loan_Amount",
    "Debt",
    "Bank_Balance"
]


for column in financial_columns:
    if column in df.columns:
        print(
            column,
            "negative values:",
            (df[column] < 0).sum()
        )
# Out:
# Monthly_Income negative values: 0
# Monthly_Expenses negative values: 0
# Monthly_Savings negative values: 0
# Loan_Amount negative values: 0
# Bank_Balance negative values: 0

# %%
import numpy as np

for column in financial_columns:
    if column in df.columns:
        df[column] = np.where(
            df[column] < 0,
            0,
            df[column]
        )

# %%
print("Missing values:")
print(df.isnull().sum().sum())


print("\nDuplicates:")
print(df.duplicated().sum())


print("\nShape:")
print(df.shape)
# Out:
# Missing values:
# 0
#
# Duplicates:
# 0
#
# Shape:
# (10000, 48)

# %%
clean_path = "../data/clean_financial_health_dataset.csv"

os.makedirs(os.path.dirname(clean_path), exist_ok=True)
df.to_csv(clean_path, index=False)

print(
    "Clean dataset saved successfully"
)
# Out:
# Clean dataset saved successfully

# %%
df.describe()
# Out:
#        Customer_ID           Age  Monthly_Income   Other_Income  \
# count  10000.00000  10000.000000    1.000000e+04   10000.000000
# mean    5000.50000     40.003700    7.787600e+05  149085.203700
# std     2886.89568     11.864736    4.156360e+05   86716.465826
# min        1.00000     20.000000    6.001100e+04      15.000000
# 25%     2500.75000     30.000000    4.181322e+05   73382.250000
# 50%     5000.50000     40.000000    7.759610e+05  148487.500000
# 75%     7500.25000     50.000000    1.135638e+06  224802.000000
# max    10000.00000     60.000000    1.499970e+06  299948.000000
#
#        Monthly_Expenses  Monthly_Savings  Emergency_Fund  Savings_Rate  \
# count      1.000000e+04     1.000000e+04    10000.000000  10000.000000
# mean       5.815533e+05     2.261699e+05   498329.367800      0.243760
# std        3.117593e+05     1.706187e+05   288583.477175      0.132983
# min        3.796500e+04     5.386000e+03      447.000000      0.030000
# 25%        3.346075e+05     9.826200e+04   252326.000000      0.140000
# 50%        5.396625e+05     1.790790e+05   493140.000000      0.220000
# 75%        7.925552e+05     3.092925e+05   749701.250000      0.330000
# max        1.554775e+06     1.062921e+06   999873.000000      0.640000
#
#         Loan_Amount  Monthly_Loan_Payment  Debt_to_Income_Ratio  Bank_Balance  \
# count  1.000000e+04           10000.00000          10000.000000  1.000000e+04
# mean   1.500685e+06           45020.04930              0.068049  9.939771e+05
# std    8.678168e+05           26034.50277              0.074810  5.773502e+05
# min    6.280000e+02              18.00000              0.000000  1.085000e+03
# 25%    7.502638e+05           22507.75000              0.020000  4.974202e+05
# 50%    1.506788e+06           45203.00000              0.050000  9.957720e+05
# 75%    2.248722e+06           67461.25000              0.080000  1.493448e+06
# max    2.999646e+06           89989.00000              1.000000  1.999924e+06
#
#        Mobile_Money_Balance  Number_of_Transactions        Cash_In  \
# count          10000.000000            10000.000000   10000.000000
# mean          250667.181100              102.804900  497985.435000
# std           144601.528383               56.469823  287814.228681
# min                0.000000                5.000000       7.000000
# 25%           126357.750000               54.000000  248567.500000
# 50%           251252.000000              102.000000  501130.000000
# 75%           374987.750000              152.000000  748084.750000
# max           499898.000000              200.000000  999854.000000
#
#            Cash_Out    Transfers  Airtime_Purchases  Monthly_Revenue  \
# count   10000.00000  10000.00000       10000.000000     1.000000e+04
# mean   498336.70550    149.03140       25139.323800     2.526418e+06
# std    290029.67164     86.50866       14547.033156     1.431781e+06
# min       146.00000      0.00000           1.000000     5.034800e+04
# 25%    245252.00000     75.00000       12378.750000     1.272734e+06
# 50%    494344.50000    149.00000       25220.000000     2.527591e+06
# 75%    751795.00000    223.00000       37834.000000     3.760620e+06
# max    999980.00000    300.00000       49989.000000     4.999623e+06
#
#        Monthly_Profit  Supplier_Payments  Invoice_Value     POS_Sales  \
# count    1.000000e+04       1.000000e+04   1.000000e+04  1.000000e+04
# mean     5.017107e+05       1.007770e+06   1.512827e+06  1.709494e+06
# std      3.769421e+05       5.754821e+05   8.667433e+05  1.077751e+06
# min      3.457000e+03       1.037600e+04   1.076100e+04  2.413000e+04
# 25%      1.994180e+05       5.140992e+05   7.580702e+05  8.109458e+05
# 50%      4.128365e+05       1.008510e+06   1.514434e+06  1.613088e+06
# 75%      7.326198e+05       1.506872e+06   2.271888e+06  2.452368e+06
# max      1.731472e+06       1.999832e+06   2.999720e+06  4.668787e+06
#
#        Investment_Value  Monthly_Return  Financial_Literacy_Score  \
# count      1.000000e+04    10000.000000              10000.000000
# mean       1.484042e+06    44372.452966                 60.203700
# std        8.638577e+05    55901.351658                 23.350609
# min        7.000000e+01   -58993.330000                 20.000000
# 25%        7.439635e+05     2489.840000                 40.000000
# 50%        1.485256e+06    28102.300000                 60.000000
# 75%        2.224296e+06    76713.260000                 80.000000
# max        2.999872e+06   236474.330000                100.000000
#
#        Spending_Discipline  Saving_Consistency  Financial_Health_Score  \
# count         10000.000000        10000.000000            10000.000000
# mean             59.848000           59.640600               44.145630
# std              23.323578           23.386627                8.918933
# min              20.000000           20.000000               15.300000
# 25%              40.000000           39.000000               37.900000
# 50%              60.000000           60.000000               44.200000
# 75%              80.000000           80.000000               50.500000
# max             100.000000          100.000000               74.600000
#
#        Predicted_Savings_12_Months  Predicted_Business_Growth
# count                 1.000000e+04               10000.000000
# mean                  2.984486e+06                   9.929500
# std                   2.283435e+06                   8.616882
# min                   6.579400e+04                  -5.000000
# 25%                   1.271768e+06                   2.500000
# 50%                   2.363585e+06                   9.900000
# 75%                   4.081266e+06                  17.200000
# max                   1.546835e+07                  25.000000

# %%
# The dataframe does not have a column named "Financial_Health".
# Use the existing "Financial_Health_Score" column instead.
df["Financial_Health_Score"].value_counts()
# Out:
# Financial_Health_Score
# 46.0    57
# 44.4    56
# 38.8    55
# 43.2    55
# 44.7    54
#         ..
# 67.5     1
# 68.9     1
# 73.1     1
# 74.6     1
# 21.0     1
# Name: count, Length: 495, dtype: int64

# %%
import seaborn as sns

sns.countplot(
    x="Financial_Health_Score",
    data=df
)

import matplotlib.pyplot as plt

sns.countplot(x="Financial_Health_Score", data=df)
plt.title("Financial Health Distribution")
plt.show()

plt.show()

plt.title(
    "Financial Health Distribution"
)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 8
#       4     x="Financial_Health_Score",
#       5     data=df
#       6 )
#       7
# ----> 8 plt.title(
#       9     "Financial Health Distribution"
#      10 )
#      11
#
# NameError: name 'plt' is not defined

# %%
pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in .\.venv\Lib\site-packages (7.3.0)
# Requirement already satisfied: comm>=0.1.1 in .\.venv\Lib\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in .\.venv\Lib\site-packages (from ipykernel) (1.8.21)
# Requirement already satisfied: ipython>=7.23.1 in .\.venv\Lib\site-packages (from ipykernel) (9.15.0)
# Requirement already satisfied: jupyter-client>=8.9.0 in .\.venv\Lib\site-packages (from ipykernel) (8.9.1)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in .\.venv\Lib\site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in .\.venv\Lib\site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: nest-asyncio2>=1.7.0 in .\.venv\Lib\site-packages (from ipykernel) (1.7.2)
# Requirement already satisfied: packaging>=22 in .\.venv\Lib\site-packages (from ipykernel) (26.2)
# Requirement already satisfied: psutil>=5.7 in .\.venv\Lib\site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in .\.venv\Lib\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in .\.venv\Lib\site-packages (from ipykernel) (6.5.7)
# Requirement already satisfied: traitlets>=5.4.0 in .\.venv\Lib\site-packages (from ipykernel) (5.15.1)
# Requirement already satisfied: colorama>=0.4.4 in .\.venv\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in .\.venv\Lib\site-packages (from ipython>=7.23.1->ipykernel) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in .\.venv\Lib\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in .\.venv\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.20.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in .\.venv\Lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in .\.venv\Lib\site-packages (from ipython>=7.23.1->ipykernel) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in .\.venv\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in .\.venv\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in .\.venv\Lib\site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel) (0.8.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\Lib\site-packages (from jupyter-client>=8.9.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=4.13.0 in .\.venv\Lib\site-packages (from jupyter-client>=8.9.0->ipykernel) (4.16.0)
# Requirement already satisfied: platformdirs>=2.5 in .\.venv\Lib\site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel) (4.11.0)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.9.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in .\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in .\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.2)
# Requirement already satisfied: pure-eval in .\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
