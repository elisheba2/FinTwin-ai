# %%
#Import libraries

# %%
import sys

# !{sys.executable} -m pip install pandas numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install matplotlib seaborn
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
    ConfusionMatrixDisplay
)

# %%
from sklearn.feature_selection import (
    mutual_info_classif,
    SelectKBest,
    f_classif
)

# %%
# %pip install xgboost
from xgboost import XGBClassifier
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install scikit-learn xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install shap
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install tqdm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !git add .
# !git commit -m "Completed preprocessing module"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# Run git command in a notebook shell (use !)
# !git branch
# Out:
# * main

# %%
# Run git pull in notebook shell
# !git pull origin main
# Out:
# Updating 9255743..6b1c660
# Fast-forward
#  Cleaned Data/cleaned_financialinclusion.csv        | 23525 ++++++++++++++
#  Cleaned Data/cleaned_personalexpense.csv           |  1001 +
#  Uncleaned Data/Financial_inclusion_dataset.csv     | 23525 ++++++++++++++
#  Uncleaned Data/Financialinclusion.ipynb            |   392 +
#  Uncleaned Data/personal_expense.ipynb              |   262 +
#  Uncleaned Data/personal_expense_dataset.csv        |  1001 +
#  Uncleaned Data/personal_finance.ipynb              |   299 +
#  .../personal_finance_tracker_dataset.csv           |  3001 ++
#  Uncleaned Data/synthetic.ipynb                     |     0
#  .../synthetic_personal_finance_dataset.csv         | 32425 +++++++++++++++++++
#  10 files changed, 85431 insertions(+)
#  create mode 100644 Cleaned Data/cleaned_financialinclusion.csv
#  create mode 100644 Cleaned Data/cleaned_personalexpense.csv
#  create mode 100644 Uncleaned Data/Financial_inclusion_dataset.csv
# ...

# %%
# !git push origin main
# Out:
# Everything up-to-date

# %%
# !git status
# !git add .
# !git commit -m "Describe what you changed"
# !git pull origin main
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Already up to date.
# From https://github.com/elisheba2/FinTwin-ai
#  * branch            main       -> FETCH_HEAD
# Everything up-to-date

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	import libraries.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git remote -v
# Out:
# origin	https://github.com/elisheba2/FinTwin-ai.git (fetch)
# origin	https://github.com/elisheba2/FinTwin-ai.git (push)

# %%
# !git add .import libraries
# Out:
# fatal: pathspec '.import' did not match any files

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	import libraries.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add "import libraries.ipynb"

# %%
# !git add .

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   import libraries.ipynb

# %%
# !git commit -m "Added library imports notebook"
# Out:
# [main b221dea] Added library imports notebook
#  1 file changed, 656 insertions(+)
#  create mode 100644 import libraries.ipynb

# %%
# !git push origin main
# Out:
# To https://github.com/elisheba2/FinTwin-ai.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/elisheba2/FinTwin-ai.git'
# hint: Updates were rejected because the remote contains work that you do not
# hint: have locally. This is usually caused by another repository pushing to
# hint: the same ref. If you want to integrate the remote changes, use
# hint: 'git pull' before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git branch
# Out:
# * main

# %%
# !git pull origin main
# Out:
# Merge made by the 'ort' strategy.
#  Cleaned Data/cleaned_personalfinance.csv |  3001 +++
#  Cleaned Data/cleaned_synthetic.csv       | 32425 +++++++++++++++++++++++++++++
#  Uncleaned Data/personal_finance.ipynb    |   415 +
#  Uncleaned Data/synthetic.ipynb           |   628 +
#  4 files changed, 36469 insertions(+)
#  create mode 100644 Cleaned Data/cleaned_personalfinance.csv
#  create mode 100644 Cleaned Data/cleaned_synthetic.csv
# From https://github.com/elisheba2/FinTwin-ai
#  * branch            main       -> FETCH_HEAD
#    6b1c660..5a98eba  main       -> origin/main

# %%
# !git push origin main
# Out:
# To https://github.com/elisheba2/FinTwin-ai.git
#    5a98eba..817becb  main -> main

# %%
file_path = "../data/Financial_Health_Digital_Twin.csv"

# %%
import os

# robustly find and list an existing data directory
candidates = ["../data"]
try:
    candidates += [os.path.dirname(p) for p in candidate_paths]
except NameError:
    pass
for v in ("file_path", "path"):
    if v in globals():
        candidates.append(os.path.dirname(globals()[v]))

# normalize and dedupe
checked = []
for c in candidates:
    if not c:
        continue
    c = os.path.abspath(os.path.expanduser(c))
    if c in checked:
        continue
    checked.append(c)
    if os.path.isdir(c):
        print("Found data directory:", c)
        print(os.listdir(c))
        break
else:
    print("No data directory found. Checked paths:")
    for p in checked:
        print("-", p)
# Out:
# Found data directory: c:\Users\eliza\Desktop\FinTwin-ai\data
# ['Financial_Health_Digital_Twin.csv']

# %%
df = pd.read_csv(file_path)

# %%
import os

os.getcwd()
# Out:
# 'c:\\Users\\eliza\\Desktop\\FinTwin-ai'

# %%
df.shape
# Out:
# (10000, 48)

# %%
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 10000
# Number of columns: 48

# %%
pd.set_option('display.max_columns', None)

df.head()
# Out:
#    Customer_ID  Age Gender       Country     Education Occupation  \
# 0            1   40      F       Nigeria       Primary      Nurse
# 1            2   27      M         Ghana  Postgraduate   Engineer
# 2            3   24      F        Rwanda       Diploma     Trader
# 3            4   51      M  South Africa       Diploma     Farmer
# 4            5   59      M         Ghana  Postgraduate     Trader
#
#   Marital_Status  Monthly_Income  Other_Income Income_Source  \
# 0         Single          376353        207001      Business
# 1        Married         1257292        161733         Mixed
# 2        Married          307601        268400      Business
# 3         Single          183636        114403        Salary
# 4         Single         1247703        167044        Salary
#
#    Monthly_Expenses  Monthly_Savings  Emergency_Fund  Savings_Rate  \
# 0            413022            59736          561913          0.10
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer_ID                  10000 non-null  int64
#  1   Age                          10000 non-null  int64
#  2   Gender                       10000 non-null  str
#  3   Country                      10000 non-null  str
#  4   Education                    10000 non-null  str
#  5   Occupation                   10000 non-null  str
#  6   Marital_Status               10000 non-null  str
#  7   Monthly_Income               10000 non-null  int64
#  8   Other_Income                 10000 non-null  int64
#  9   Income_Source                10000 non-null  str
#  10  Monthly_Expenses             10000 non-null  int64
#  11  Monthly_Savings              10000 non-null  int64
#  12  Emergency_Fund               10000 non-null  int64
# ...

# %%
missing_values = df.isnull().sum()

missing_values[missing_values > 0].sort_values(
    ascending=False
)
# Out:
# Series([], dtype: int64)

# %%
missing_percentage = (
    df.isnull().sum() / len(df) * 100
)

missing_percentage[
    missing_percentage > 0
].sort_values(
    ascending=False
)
# Out:
# Series([], dtype: float64)

# %%
duplicates = df.duplicated().sum()

print(
    "Duplicate rows:",
    duplicates
)
# Out:
# Duplicate rows: 0

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.replace(" ", "_")
    .str.replace("-", "_")
)

df.columns
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'Country', 'Education', 'Occupation',
#        'Marital_Status', 'Monthly_Income', 'Other_Income', 'Income_Source',
#        'Monthly_Expenses', 'Monthly_Savings', 'Emergency_Fund', 'Savings_Rate',
#        'Loan_Amount', 'Monthly_Loan_Payment', 'Debt_to_Income_Ratio',
#        'Bank_Balance', 'Mobile_Money_Balance', 'Number_of_Transactions',
#        'Cash_In', 'Cash_Out', 'Transfers', 'Airtime_Purchases',
#        'Business_Type', 'Monthly_Revenue', 'Monthly_Profit',
#        'Supplier_Payments', 'Invoice_Value', 'POS_Sales', 'Investment_Type',
#        'Investment_Value', 'Monthly_Return', 'Financial_Literacy_Score',
#        'Spending_Discipline', 'Risk_Tolerance', 'Saving_Consistency',
#        'Financial_Goal', 'Financial_Health_Score', 'Funding_Readiness',
#        'Investment_Readiness', 'Loan_Default_Risk',
#        'Predicted_Savings_12_Months', 'Predicted_Business_Growth',
# ...

# %%
duplicate_columns = df.columns[
    df.columns.duplicated()
]

duplicate_columns
# Out:
# Index([], dtype='str')

# %%
numeric_columns = df.select_dtypes(include='number').columns

numeric_columns

numeric_columns
# Out:
# Index(['Customer_ID', 'Age', 'Monthly_Income', 'Other_Income',
#        'Monthly_Expenses', 'Monthly_Savings', 'Emergency_Fund', 'Savings_Rate',
#        'Loan_Amount', 'Monthly_Loan_Payment', 'Debt_to_Income_Ratio',
#        'Bank_Balance', 'Mobile_Money_Balance', 'Number_of_Transactions',
#        'Cash_In', 'Cash_Out', 'Transfers', 'Airtime_Purchases',
#        'Monthly_Revenue', 'Monthly_Profit', 'Supplier_Payments',
#        'Invoice_Value', 'POS_Sales', 'Investment_Value', 'Monthly_Return',
#        'Financial_Literacy_Score', 'Spending_Discipline', 'Saving_Consistency',
#        'Financial_Health_Score', 'Predicted_Savings_12_Months',
#        'Predicted_Business_Growth'],
#       dtype='str')

# %%
for column in df.select_dtypes(include='number').columns:
    df[column] = df[column].fillna(df[column].median())

# %%
financial_columns = [
    "Monthly_Income",
    "Monthly_Expenses",
    "Monthly_Savings",
    "Loan_Amount",
    "Debt",
    "Bank_Balance"
]


for column in financial_columns:
    if column in df.columns:
        print(
            column,
            "negative values:",
            (df[column] < 0).sum()
        )
# Out:
# Monthly_Income negative values: 0
# Monthly_Expenses negative values: 0
# Monthly_Savings negative values: 0
# Loan_Amount negative values: 0
# Bank_Balance negative values: 0

# %%
import numpy as np

for column in financial_columns:
    if column in df.columns:
        df[column] = np.where(
            df[column] < 0,
            0,
            df[column]
        )

# %%
print("Missing values:")
print(df.isnull().sum().sum())


print("\nDuplicates:")
print(df.duplicated().sum())


print("\nShape:")
print(df.shape)
# Out:
# Missing values:
# 0
#
# Duplicates:
# 0
#
# Shape:
# (10000, 48)

# %%
clean_path = "../data/clean_financial_health_dataset.csv"

os.makedirs(os.path.dirname(clean_path), exist_ok=True)
df.to_csv(clean_path, index=False)

print(
    "Clean dataset saved successfully"
)
# Out:
# Clean dataset saved successfully

# %%
df.describe()
# Out:
#        Customer_ID           Age  Monthly_Income   Other_Income  \
# count  10000.00000  10000.000000    1.000000e+04   10000.000000
# mean    5000.50000     40.003700    7.787600e+05  149085.203700
# std     2886.89568     11.864736    4.156360e+05   86716.465826
# min        1.00000     20.000000    6.001100e+04      15.000000
# 25%     2500.75000     30.000000    4.181322e+05   73382.250000
# 50%     5000.50000     40.000000    7.759610e+05  148487.500000
# 75%     7500.25000     50.000000    1.135638e+06  224802.000000
# max    10000.00000     60.000000    1.499970e+06  299948.000000
#
#        Monthly_Expenses  Monthly_Savings  Emergency_Fund  Savings_Rate  \
# count      1.000000e+04     1.000000e+04    10000.000000  10000.000000
# mean       5.815533e+05     2.261699e+05   498329.367800      0.243760
# std        3.117593e+05     1.706187e+05   288583.477175      0.132983
# min        3.796500e+04     5.386000e+03      447.000000      0.030000
# ...

# %%
# The dataframe does not have a column named "Financial_Health".
# Use the existing "Financial_Health_Score" column instead.
df["Financial_Health_Score"].value_counts()
# Out:
# Financial_Health_Score
# 46.0    57
# 44.4    56
# 38.8    55
# 43.2    55
# 44.7    54
#         ..
# 67.5     1
# 68.9     1
# 73.1     1
# 74.6     1
# 21.0     1
# Name: count, Length: 495, dtype: int64

# %%
import seaborn as sns

sns.countplot(
    x="Financial_Health_Score",
    data=df
)

import matplotlib.pyplot as plt

sns.countplot(x="Financial_Health_Score", data=df)
plt.title("Financial Health Distribution")
plt.show()

plt.show()

plt.title(
    "Financial Health Distribution"
)

plt.show()

# %%
df.to_csv("data/clean_financial_health_dataset.csv", index=False)

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# c:\Users\eliza\Desktop\FinTwin-ai
# ['.git', 'Cleaned Data', 'data', 'Financial_Health_Digital_Twin.csv', 'fintwin_env', 'import libraries.ipynb', 'README.md', 'Uncleaned Data']
